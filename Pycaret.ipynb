# %% [markdown]
# # Tarea Final - Machine Learning
#
# Alumno: Guillermo Lodeiro
#
# Profesores: Jose Angel Carballo, Luis Garmendia, María José Gómez
#
# Institución: Universidad Complutense de Madrid
#
# Comienzo utilizando Pycaret con mi data preprocesada, el mejor algoritmo siempre fue Random Forest por lo que decidi utilizar este algoritmo para el trabajo.

# %%
import pandas as pd

# %%
# Cargo los datos ya preprocesados.

datos_limpios = pd.read_csv('training_set_values_pp6.csv')

# %%
from pycaret.classification import *

# Inicializo la configuración de Pycaret.

exp_clf = setup(data=datos_limpios, target='status_group', session_id=42, preprocess=False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b31f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b31f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6b31f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b31f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b31f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6b31f_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_6b31f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6b31f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6b31f_row1_col1" class="data row1 col1" >status_group</td>
#     </tr>
#     <tr>
#       <th id="T_6b31f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6b31f_row2_col0" class="data row2 col0" >Target type</td>
# ...

# %%
# Comparo los modelos.

best_model = compare_models()
# Out:
# <style type="text/css">
# #T_ee5f0 th {
#   text-align: left;
# }
# ...

# %%
# Ajuste del modelo con los parametros óptimos para el caso.

final_model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_41cbe_row10_col0, #T_41cbe_row10_col1, #T_41cbe_row10_col2, #T_41cbe_row10_col3, #T_41cbe_row10_col4, #T_41cbe_row10_col5, #T_41cbe_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_41cbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41cbe_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_41cbe_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_41cbe_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_41cbe_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_41cbe_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_41cbe_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_41cbe_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# Prueba de nuevos hiperparámetros mediante tune_model.

tuned_model = tune_model(final_model)
# Out:
# <style type="text/css">
# #T_0db6e_row10_col0, #T_0db6e_row10_col1, #T_0db6e_row10_col2, #T_0db6e_row10_col3, #T_0db6e_row10_col4, #T_0db6e_row10_col5, #T_0db6e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0db6e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0db6e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0db6e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0db6e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0db6e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0db6e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0db6e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0db6e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
# Evaluación del modelo final, elijo final_model ya que tuned_model no mejoro.

evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
